# %%
from alpaca.data import StockHistoricalDataClient
from alpaca.data.requests import StockBarsRequest
from alpaca.data.timeframe import TimeFrame
from datetime import datetime
import pandas as pd

# %%
stock_client = StockHistoricalDataClient("PKMLLNTM0501EGB032TH",  "zwqHgD9dFwn71OwvAU4TdPe736omCZvf6pcOUg4n")

# %%
request_params = StockBarsRequest(
                        symbol_or_symbols=["TQQQ"],
                        timeframe=TimeFrame.Minute,
                        start=datetime(2024, 2, 17),
                        end=datetime(2024, 3, 17)
                 )

bars = stock_client.get_stock_bars(request_params)

# %%
json1 = dict(bars)
data = json1['data']['TQQQ']

# %%
,) 
df
# Out:
#                     0                                       1  \
# 0      (symbol, TQQQ)  (timestamp, 2024-02-17 00:01:00+00:00)
# 1      (symbol, TQQQ)  (timestamp, 2024-02-17 00:02:00+00:00)
# 2      (symbol, TQQQ)  (timestamp, 2024-02-17 00:03:00+00:00)
# 3      (symbol, TQQQ)  (timestamp, 2024-02-17 00:04:00+00:00)
# 4      (symbol, TQQQ)  (timestamp, 2024-02-17 00:05:00+00:00)
# ...               ...                                     ...
# 17465  (symbol, TQQQ)  (timestamp, 2024-03-15 23:55:00+00:00)
# 17466  (symbol, TQQQ)  (timestamp, 2024-03-15 23:56:00+00:00)
# 17467  (symbol, TQQQ)  (timestamp, 2024-03-15 23:57:00+00:00)
# 17468  (symbol, TQQQ)  (timestamp, 2024-03-15 23:58:00+00:00)
# 17469  (symbol, TQQQ)  (timestamp, 2024-03-15 23:59:00+00:00)
#
#                      2                3               4               5  \
# 0        (open, 57.22)    (high, 57.22)    (low, 57.22)  (close, 57.22)
# 1        (open, 57.22)    (high, 57.22)    (low, 57.21)  (close, 57.21)
# ...

# %%
tmp=tqqq.groupby(pd.Grouper(freq='5min')).agg({"open": "first", "high": "max", "low": "min", "close": "last", "volume": "sum", "trade_count":"sum", "vwap":"last"})
tmp.index=tmp.index.floor(freq='5min')+pd.Timedelta(minutes=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 tmp=tqqq.groupby(pd.Grouper(freq='5min')).agg({"open": "first", "high": "max", "low": "min", "close": "last", "volume": "sum", "trade_count":"sum", "vwap":"last"})
#       2 tmp.index=tmp.index.floor(freq='5min')+pd.Timedelta(minutes=5)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:8869, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8866 if level is None and by is None:
#    8867     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8869 return DataFrameGroupBy(
#    8870     obj=self,
#    8871     keys=by,
#    8872     axis=axis,
#    8873     level=level,
#    8874     as_index=as_index,
#    8875     sort=sort,
# ...
